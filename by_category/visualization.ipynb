# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn 
import scipy.stats as ss

# %%
movies = pd.read_csv('../data_analysis/sources/Movies.csv')
movies.Popularity.plot(kind='box', vert=False)
# Out:
# <Axes: >

# %%
movies.head()
movies.Duration.plot(kind='density', figsize=(15, 5));

# %%
movies.Rating.plot(kind='hist', figsize=(15, 5))
# Out:
# <Axes: ylabel='Frequency'>

# %%
sn.kdeplot(movies.Rating);

# %%
sn.boxplot(movies.Rating);

# %%
sn.scatterplot(x=movies.Duration, y=movies.Rating)
# Out:
# <Axes: xlabel='Duration', ylabel='Rating'>

# %%
x = movies.Duration.plot(kind='kde');
x.axvline(movies.Duration.mean(), color='red')
x.axvline(movies.Duration.median(), color='green')

# %%
x = movies.Rating.plot(kind = 'kde')
x.set_ylabel("hey")
x.set_xlabel('hoy')
# Out:
# Text(0.5, 0, 'hoy')

# %%
movies.Genre.value_counts().plot(kind='pie')
# Out:
# <Axes: >

# %%
crosstab = pd.crosstab(movies.Rating, movies.Duration, normalize=False)
sn.heatmap(crosstab)
# Out:
# <Axes: xlabel='Duration', ylabel='Rating'>
