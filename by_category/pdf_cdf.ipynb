# %%
# pdf => probability density function
# Dağılımın şekli.
# Her değerin ne kadar olası olduğunu gösteren fonksiyon.

# 170
# 171
# 169
# 172
# 168
# 170
# 171

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %%
# CDF (Cumulative Distribution Function)
# CDF(170)=0.43 ===> Rastgele seçilen bir öğrencinin boyunun 170 veya daha kısa olma olasılığı %43'tür.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
#
# ![image.png](attachment:image.png)
#
# ![image-3.png](attachment:image-3.png)
