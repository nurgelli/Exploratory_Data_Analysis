# %% [markdown]
# > Probability

# %% [markdown]
# <!-- Probabili  -->

# %%
# independent event ==> tossing head or tail in sample space 1 will not impact head eiher tail
# dependent event ==> choosing king of diamond from 36 and keep choesen one will impact next choice
# mutual exclusive event ==> student A apply to law, student B apply to Medicine, not bot of them
# not mutual exclusive ==> studen A can apply to Law and Medicine


# Multiplication
# Probability of two independent events E1 and E2 both occuring is written as:
# P(E1 and E2) = P(E1) * P(E2)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Addition
# Probability of two E1 and E2 occuring is written as:

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)
# ![image.png](attachment:image.png)

# %%
# Multiplication ==> bir sansindan 3,4,5 almak

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Addition ===> bir sansa 3 ya da 4 ya da 5 atmak

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
40 + 60 - 30
# Out:
# 70

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Titanic survivors

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import pandas as pd

# Females probability in titanic
female = 466 / 1309
np.around(female * 100)
# Out:
# np.float64(36.0)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import math
# what is the probability that a passanger survived given they are female?

# P(survived | female) = Number of passenger survived / total passenger 

p_survived = 339 / 466
round(p_survived * 100)
# Out:
# 73

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %%
survived_female = 466 * (339 / 466)
survived_female
# Out:
# 339.0

# %%
multi_survived_fem = (339 / 1309) / (466 / 1309)
round(multi_survived_fem * 100)
# Out:
# 73

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# P(survived | male)
p_survived_male = 161 / 843
round(p_survived_male * 100)
# Out:
# 19

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 1st class passenger
p_1st_class = 200 / 323
np.around(p_1st_class * 100)
# Out:
# np.float64(62.0)

# %%
# 2st class passenger
p_2nd_class = 119 / 277
np.around(p_2nd_class * 100)
# Out:
# np.float64(43.0)

# %%
# 3st class passenger
p_3rd_class = 181 / 528
round(p_3rd_class * 100)
# Out:
# 34

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
male_1st_class = 61 / 179
round(male_1st_class * 100)
# Out:
# 34

# %%
male_2nd_class = 25 / 146
round(male_2nd_class * 100)
# Out:
# 17

# %%
male_3rd_class = 75 / 493
round(male_3rd_class * 100)
# Out:
# 15

# %%
female_1st_class = 139 / 144
round(female_1st_class * 100)
# Out:
# 97

# %%
female_2nd_class = 94 / 106
round(female_2nd_class * 100)
# Out:
# 89

# %%
female_3rd_class = 106 / 216
round(female_3rd_class * 100)
# Out:
# 49

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
female_survived_passenger = 339 / 1309
round(female_survived_passenger * 100)
# Out:
# 26

# %%
male_survived_passenger = 161 / 1309
round(male_survived_passenger * 100)
# Out:
# 12

# %% [markdown]
# > Bayes Theorem

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
fem_surv = 339 / 500
p_fem_surv = 38.2 * 67.8 / 35.6
p_fem_surv
# Out:
# 72.75168539325843

# %%
surved_fem = np.around(339 / p_fem_surv *100) #===> to get 73 as a count
surved_fem
# Out:
# np.float64(466.0)

# %%
not_survived_fem = np.around(339 / p_fem_surv * 100) - 339
not_survived_fem
# Out:
# np.float64(127.0)

# %%
male_surve = 161 / 500
p_male_surve = 38.2 * male_surve / 64.4
p_male_surve
# Out:
# 0.191

# %%
total_male = round(161 / p_male_surve)
total_male
# Out:
# 843

# %%
not_sur_male = total_male - 161
not_sur_male
# Out:
# 682

# %%
surved_fem + total_male
# Out:
# np.float64(1309.0)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Spam

spam = 11 / 100
print(spam)

deal = 10 / 100
print(deal)

deal_spam = 9 / 11
print(deal_spam)
# Out:
# 0.11
# 0.1
# 0.8181818181818182

# %%
p_spam_deal = 11 * 82 / 10
p_spam_deal
# Out:
# 90.2

# %%
spam_in_total = 11 / 100
farzan_in_total = 90 / 100 
farzan_spam = 2 / 11

p_farzan_spam = spam_in_total * farzan_spam / farzan_in_total
p_farzan_spam
# Out:
# 0.022222222222222223

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
# P(A|B) = A*B|A / B
# P(B|A) = B*A|B / A
